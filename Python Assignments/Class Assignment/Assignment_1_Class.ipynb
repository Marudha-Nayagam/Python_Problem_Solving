# %%
from multipleFunctions import SubfieldsInAI, OddEven, ElegiblityForMarriage, FindPercent, Triangle

# %%
# Create a class and function, and list out the items in the list
SubfieldsInAI.subfieldsInAI()
# Out:
# Sub-fieldls in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a function that checks whether the given number is Odd or Even
OddEven.oddEven()
# Out:
# enter a number:  52542
# '52542 is Even Number'

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female
ElegiblityForMarriage.marraige_eligibility()
# Out:
# Your Gender: FEmale
# Your Age: 13
# 'NOT ELIGIBLE'

# %%
# calculate the percentage of your 10th mark
FindPercent.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total :468
# Percentage : 93.6

# %%
#print area and perimeter of triangle using class and functions
Triangle.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
