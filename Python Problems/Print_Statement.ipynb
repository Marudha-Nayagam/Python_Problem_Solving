# %%
print()

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
Print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print()
#
# NameError: name 'Print' is not defined

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print("hello")
# Out:
# hello

# %%
print("My name is Marudha Nayagam")
# Out:
# My name is Marudha Nayagam

# %%
name = "Marudha Nayagam"
print("My name is",name)
# Out:
# My name is Marudha Nayagam
