# %%
# Take two numbers from the user and print the sum.
n1 = int(input("enter number 1: "))
n2 = int(input("enter number 2: "))

add = n1 + n2
print(add)
# Out:
# enter number 1:  58
# enter number 2:  -9
# 49
